# %%
# Instale o Unsloth (suporta Llama, Mistral, etc. com otimizações)
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"

# Bibliotecas de Machine Learning e LangChain
# !pip install -U "transformers==4.41.2" "datasets[audio]" "accelerate" "bitsandbytes" "peft"
# !pip install -U langchain langgraph langchain_core langchain_community langchain_openai

# Bibliotecas de visualização
# !pip install matplotlib seaborn plotly kaleido
# Out:
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-90uneu7y/unsloth_2996833c4f684c72850455a1255ddfad
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-90uneu7y/unsloth_2996833c4f684c72850455a1255ddfad
#   Resolved https://github.com/unslothai/unsloth.git to commit cc29dc5c35002546009fa2d488a3f726c04922b8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# INFO: pip is looking at multiple versions of unsloth to determine which version is compatible with other requirements. This could take a while.
# ERROR: Package 'unsloth' requires a different Python: 3.13.2 not in '<3.13,>=3.9'
# Collecting transformers==4.41.2
#   Downloading transformers-4.41.2-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: accelerate in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (1.4.0)
# Collecting accelerate
#   Downloading accelerate-1.8.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: bitsandbytes in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.45.3)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: peft in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.14.0)
# Collecting peft
#   Downloading peft-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: datasets[audio] in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (3.3.2)
# Collecting datasets[audio]
#   Using cached datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from transformers==4.41.2) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from transformers==4.41.2) (0.30.1)
# Requirement already satisfied: numpy>=1.17 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from transformers==4.41.2) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from transformers==4.41.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from transformers==4.41.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from transformers==4.41.2) (2024.11.6)
# Requirement already satisfied: requests in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from transformers==4.41.2) (2.32.3)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.41.2)
#   Downloading tokenizers-0.19.1.tar.gz (321 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: safetensors>=0.4.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from transformers==4.41.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from transformers==4.41.2) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from datasets[audio]) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from datasets[audio]) (0.3.8)
# Requirement already satisfied: pandas in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from datasets[audio]) (2.2.3)
# Requirement already satisfied: xxhash in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from datasets[audio]) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from datasets[audio]) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (2024.12.0)
# Collecting soundfile>=0.12.1 (from datasets[audio])
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting librosa (from datasets[audio])
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting soxr>=0.4.0 (from datasets[audio])
#   Downloading soxr-0.5.0.post1-cp312-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: psutil in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: torch>=2.0.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from accelerate) (2.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (3.11.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (4.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests->transformers==4.41.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests->transformers==4.41.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests->transformers==4.41.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests->transformers==4.41.2) (2025.1.31)
# Collecting cffi>=1.0 (from soundfile>=0.12.1->datasets[audio])
#   Downloading cffi-1.17.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: networkx in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: setuptools in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (75.8.2)
# Requirement already satisfied: sympy==1.13.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Collecting audioread>=2.1.9 (from librosa->datasets[audio])
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numba>=0.51.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from librosa->datasets[audio]) (0.61.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from librosa->datasets[audio]) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from librosa->datasets[audio]) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from librosa->datasets[audio]) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from librosa->datasets[audio]) (5.2.1)
# Collecting pooch>=1.1 (from librosa->datasets[audio])
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: lazy_loader>=0.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from librosa->datasets[audio]) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from librosa->datasets[audio]) (1.1.0)
# Collecting standard-aifc (from librosa->datasets[audio])
#   Downloading standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting standard-sunau (from librosa->datasets[audio])
#   Downloading standard_sunau-3.13.0-py3-none-any.whl.metadata (914 bytes)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pandas->datasets[audio]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pandas->datasets[audio]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pandas->datasets[audio]) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (1.18.3)
# Collecting pycparser (from cffi>=1.0->soundfile>=0.12.1->datasets[audio])
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from numba>=0.51.0->librosa->datasets[audio]) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pooch>=1.1->librosa->datasets[audio]) (4.3.6)
# Requirement already satisfied: six>=1.5 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets[audio]) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from scikit-learn>=1.1.0->librosa->datasets[audio]) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Collecting standard-chunk (from standard-aifc->librosa->datasets[audio])
#   Downloading standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Collecting audioop-lts (from standard-aifc->librosa->datasets[audio])
#   Downloading audioop_lts-0.2.1-cp313-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.6 kB)
# Downloading transformers-4.41.2-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 27.3 MB/s eta 0:00:00a 0:00:01
# Downloading accelerate-1.8.1-py3-none-any.whl (365 kB)
# Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 34.4 MB/s eta 0:00:0000:0100:01
# Downloading peft-0.16.0-py3-none-any.whl (472 kB)
# Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.3 MB/s eta 0:00:00
# Downloading soxr-0.5.0.post1-cp312-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (248 kB)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading cffi-1.17.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (479 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Downloading standard_sunau-3.13.0-py3-none-any.whl (7.4 kB)
# Downloading audioop_lts-0.2.1-cp313-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (82 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Downloading standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Building wheels for collected packages: tokenizers
#   Building wheel for tokenizers (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [83 lines of output]
#       Running `maturin pep517 build-wheel -i /home/danilo/anaconda3/envs/mestrado/bin/python3.13 --compatibility off`
#       Rust not found, installing into a temporary directory
#       Python reports SOABI: cpython-313-x86_64-linux-gnu
#       Computed rustc target triple: x86_64-unknown-linux-gnu
#       Installation directory: /home/danilo/.var/app/com.visualstudio.code/cache/puccinialin
#       Rustup already downloaded
#       Installing rust to /home/danilo/.var/app/com.visualstudio.code/cache/puccinialin/rustup
#       warn: It looks like you have an existing rustup settings file at:
#       warn: /home/danilo/.rustup/settings.toml
#       warn: Rustup will install the default toolchain as specified in the settings file,
#       warn: instead of the one inferred from the default host triple.
#       info: profile set to 'minimal'
#       info: default host triple is x86_64-unknown-linux-gnu
#       warn: Updating existing toolchain, profile choice will be ignored
#       info: syncing channel updates for 'stable-x86_64-unknown-linux-gnu'
#       info: default toolchain set to 'stable-x86_64-unknown-linux-gnu'
#       Checking if cargo is installed
#       cargo 1.88.0 (873a06493 2025-05-10)
#       ⚠️  Warning: `project.version` field is required in pyproject.toml unless it is present in the `project.dynamic` list
#       🍹 Building a mixed python/rust project
#       🔗 Found pyo3 bindings
#       🐍 Found CPython 3.13 at /home/danilo/anaconda3/envs/mestrado/bin/python3.13
#       📡 Using build options features, bindings from pyproject.toml
#          Compiling proc-macro2 v1.0.81
#          Compiling unicode-ident v1.0.12
#          Compiling autocfg v1.2.0
#          Compiling libc v0.2.153
#          Compiling target-lexicon v0.12.14
#          Compiling once_cell v1.19.0
#          Compiling cfg-if v1.0.0
#          Compiling memchr v2.7.2
#          Compiling crossbeam-utils v0.8.19
#          Compiling cc v1.0.94
#          Compiling ident_case v1.0.1
#          Compiling strsim v0.10.0
#          Compiling fnv v1.0.7
#          Compiling num-traits v0.2.18
#          Compiling serde v1.0.198
#          Compiling smallvec v1.13.2
#          Compiling portable-atomic v1.6.0
#          Compiling quote v1.0.36
#          Compiling pyo3-build-config v0.21.2
#          Compiling syn v2.0.60
#          Compiling crossbeam-epoch v0.9.18
#          Compiling aho-corasick v1.1.3
#          Compiling lock_api v0.4.11
#          Compiling rayon-core v1.12.1
#          Compiling either v1.11.0
#          Compiling pkg-config v0.3.30
#          Compiling parking_lot_core v0.9.9
#          Compiling regex-syntax v0.8.3
#          Compiling crossbeam-deque v0.8.5
#          Compiling getrandom v0.2.14
#          Compiling onig_sys v69.8.1
#          Compiling matrixmultiply v0.3.8
#          Compiling memoffset v0.9.1
#          Compiling paste v1.0.14
#          Compiling heck v0.4.1
#          Compiling scopeguard v1.2.0
#          Compiling pyo3-ffi v0.21.2
#          Compiling pyo3 v0.21.2
#          Compiling rand_core v0.6.4
#       error: failed to run custom build command for `pyo3-ffi v0.21.2`
#
#       Caused by:
#         process didn't exit successfully: `/tmp/pip-install-8lmhw3jf/tokenizers_ee84b61e9e4b472c84ac20b78ebc31e0/bindings/python/target/release/build/pyo3-ffi-07bde6606b560ac2/build-script-build` (exit status: 1)
#         --- stdout
#         cargo:rerun-if-env-changed=PYO3_CROSS
#         cargo:rerun-if-env-changed=PYO3_CROSS_LIB_DIR
#         cargo:rerun-if-env-changed=PYO3_CROSS_PYTHON_VERSION
#         cargo:rerun-if-env-changed=PYO3_CROSS_PYTHON_IMPLEMENTATION
#         cargo:rerun-if-env-changed=PYO3_PRINT_CONFIG
#         cargo:rerun-if-env-changed=PYO3_USE_ABI3_FORWARD_COMPATIBILITY
#
#         --- stderr
#         error: the configured Python interpreter version (3.13) is newer than PyO3's maximum supported version (3.12)
#         = help: please check if an updated version of PyO3 is available. Current version: 0.21.2
#         = help: set PYO3_USE_ABI3_FORWARD_COMPATIBILITY=1 to suppress this check and build anyway using the stable ABI
#       warning: build failed, waiting for other jobs to finish...
#       💥 maturin failed
#         Caused by: Failed to build a native library through cargo
#         Caused by: Cargo build finished with "exit status: 101": `env -u CARGO PYO3_ENVIRONMENT_SIGNATURE="cpython-3.13-64bit" PYO3_PYTHON="/home/danilo/anaconda3/envs/mestrado/bin/python3.13" PYTHON_SYS_EXECUTABLE="/home/danilo/anaconda3/envs/mestrado/bin/python3.13" "cargo" "rustc" "--features" "pyo3/extension-module" "--message-format" "json-render-diagnostics" "--manifest-path" "/tmp/pip-install-8lmhw3jf/tokenizers_ee84b61e9e4b472c84ac20b78ebc31e0/bindings/python/Cargo.toml" "--release" "--lib"`
#       Error: command ['maturin', 'pep517', 'build-wheel', '-i', '/home/danilo/anaconda3/envs/mestrado/bin/python3.13', '--compatibility', 'off'] returned non-zero exit status 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (tokenizers)
# Requirement already satisfied: langchain in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.3.19)
# Collecting langchain
#   Downloading langchain-0.3.26-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: langgraph in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.3.1)
# Collecting langgraph
#   Downloading langgraph-0.5.1-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: langchain_core in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.3.40)
# Collecting langchain_core
#   Downloading langchain_core-0.3.68-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain_community in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.3.18)
# Collecting langchain_community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain_openai in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.3.7)
# Collecting langchain_openai
#   Downloading langchain_openai-0.3.27-py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Downloading langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: langsmith>=0.1.17 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (6.0.2)
# Collecting langgraph-checkpoint<3.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-2.1.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<0.6.0,>=0.5.0 (from langgraph)
#   Downloading langgraph_prebuilt-0.5.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph) (0.1.53)
# Requirement already satisfied: xxhash>=3.5.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph) (3.5.0)
# Collecting langsmith>=0.1.17 (from langchain)
#   Downloading langsmith-0.4.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain_core) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain_core) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain_core) (4.14.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain_community) (3.11.13)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain_community) (2.8.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy>=2.1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain_community) (2.2.3)
# Collecting openai<2.0.0,>=1.86.0 (from langchain_openai)
#   Downloading openai-1.93.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain_openai) (0.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.10.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
# Requirement already satisfied: httpx>=0.25.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (0.8.2)
# Requirement already satisfied: sniffio in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.11.6)
# Requirement already satisfied: httpcore==1.* in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Downloading langchain-0.3.26-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 7.9 MB/s eta 0:00:00
# Downloading langgraph-0.5.1-py3-none-any.whl (143 kB)
# Downloading langchain_core-0.3.68-py3-none-any.whl (441 kB)
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 15.4 MB/s eta 0:00:00
# Downloading langchain_openai-0.3.27-py3-none-any.whl (70 kB)
# Downloading langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Downloading langgraph_checkpoint-2.1.0-py3-none-any.whl (43 kB)
# Downloading langgraph_prebuilt-0.5.2-py3-none-any.whl (23 kB)
# Downloading langsmith-0.4.4-py3-none-any.whl (367 kB)
# Downloading openai-1.93.0-py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.0/755.0 kB 10.8 MB/s eta 0:00:00
# Downloading ormsgpack-1.10.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (216 kB)
# Installing collected packages: ormsgpack, openai, langsmith, langchain_core, langgraph-checkpoint, langchain-text-splitters, langchain_openai, langgraph-prebuilt, langchain, langgraph, langchain_community
#   Attempting uninstall: openai
#     Found existing installation: openai 1.65.2
#     Uninstalling openai-1.65.2:
#       Successfully uninstalled openai-1.65.2
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.11
#     Uninstalling langsmith-0.3.11:
#       Successfully uninstalled langsmith-0.3.11
#   Attempting uninstall: langchain_core
#     Found existing installation: langchain-core 0.3.40
#     Uninstalling langchain-core-0.3.40:
#       Successfully uninstalled langchain-core-0.3.40
#   Attempting uninstall: langgraph-checkpoint
#     Found existing installation: langgraph-checkpoint 2.0.16
#     Uninstalling langgraph-checkpoint-2.0.16:
#       Successfully uninstalled langgraph-checkpoint-2.0.16
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.6
#     Uninstalling langchain-text-splitters-0.3.6:
#       Successfully uninstalled langchain-text-splitters-0.3.6
#   Attempting uninstall: langchain_openai
#     Found existing installation: langchain-openai 0.3.7
#     Uninstalling langchain-openai-0.3.7:
#       Successfully uninstalled langchain-openai-0.3.7
#   Attempting uninstall: langgraph-prebuilt
#     Found existing installation: langgraph-prebuilt 0.1.1
#     Uninstalling langgraph-prebuilt-0.1.1:
#       Successfully uninstalled langgraph-prebuilt-0.1.1
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.19
#     Uninstalling langchain-0.3.19:
#       Successfully uninstalled langchain-0.3.19
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 0.3.1
#     Uninstalling langgraph-0.3.1:
#       Successfully uninstalled langgraph-0.3.1
#   Attempting uninstall: langchain_community
#     Found existing installation: langchain-community 0.3.18
#     Uninstalling langchain-community-0.3.18:
#       Successfully uninstalled langchain-community-0.3.18
# Successfully installed langchain-0.3.26 langchain-text-splitters-0.3.8 langchain_community-0.3.27 langchain_core-0.3.68 langchain_openai-0.3.27 langgraph-0.5.1 langgraph-checkpoint-2.1.0 langgraph-prebuilt-0.5.2 langsmith-0.4.4 openai-1.93.0 ormsgpack-1.10.0
# Requirement already satisfied: matplotlib in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (3.10.0)
# Requirement already satisfied: seaborn in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.13.2)
# Collecting plotly
#   Downloading plotly-6.2.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting kaleido
#   Downloading kaleido-1.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from seaborn) (2.2.3)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.45.0-py3-none-any.whl.metadata (11 kB)
# Collecting choreographer>=1.0.5 (from kaleido)
#   Downloading choreographer-1.0.9-py3-none-any.whl.metadata (5.6 kB)
# Collecting logistro>=1.0.8 (from kaleido)
#   Downloading logistro-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: orjson>=3.10.15 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from kaleido) (3.10.15)
# Collecting simplejson>=3.19.3 (from choreographer>=1.0.5->kaleido)
#   Downloading simplejson-3.20.1-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading plotly-6.2.0-py3-none-any.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 25.3 MB/s eta 0:00:0000:0100:01
# Downloading kaleido-1.0.0-py3-none-any.whl (51 kB)
# Downloading choreographer-1.0.9-py3-none-any.whl (51 kB)
# Downloading logistro-1.1.0-py3-none-any.whl (7.9 kB)
# Downloading narwhals-1.45.0-py3-none-any.whl (371 kB)
# Downloading simplejson-3.20.1-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (152 kB)
# Installing collected packages: simplejson, narwhals, logistro, plotly, choreographer, kaleido
# Successfully installed choreographer-1.0.9 kaleido-1.0.0 logistro-1.1.0 narwhals-1.45.0 plotly-6.2.0 simplejson-3.20.1

# %%
# !pip install langchain langgraph langchain-community langchain-ollama pandas plotly seaborn matplotlib
# Out:
# Requirement already satisfied: langchain in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.3.26)
# Requirement already satisfied: langgraph in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.5.1)
# Requirement already satisfied: langchain-community in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.3.27)
# Collecting langchain-ollama
#   Downloading langchain_ollama-0.3.3-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pandas in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: plotly in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (6.2.0)
# Requirement already satisfied: seaborn in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (3.10.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (0.3.68)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (0.4.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph) (2.1.0)
# Requirement already satisfied: langgraph-prebuilt<0.6.0,>=0.5.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph) (0.5.2)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph) (0.1.53)
# Requirement already satisfied: xxhash>=3.5.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain-community) (3.11.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=2.1.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain-community) (2.2.3)
# Collecting ollama<1.0.0,>=0.4.8 (from langchain-ollama)
#   Downloading ollama-0.5.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: narwhals>=1.15.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from plotly) (1.45.0)
# Requirement already satisfied: packaging in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from plotly) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: httpx>=0.25.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: six>=1.5 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /home/danilo/anaconda3/envs/mestrado/lib/python3.13/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.3.1)
# Downloading langchain_ollama-0.3.3-py3-none-any.whl (21 kB)
# Downloading ollama-0.5.1-py3-none-any.whl (13 kB)
# Installing collected packages: ollama, langchain-ollama
# Successfully installed langchain-ollama-0.3.3 ollama-0.5.1

# %%
# cniongolo/biomistral
# Out:
# /bin/sh: linha 1: ollama: comando não encontrado

# %%
# --- 0. IMPORTAÇÃO DE BIBLIOTECAS ---
import json
import base64
from io import BytesIO
from typing import TypedDict, List, Dict

# Libs de Visualização
import pandas as pd
import plotly.express as px
import plotly.io as pio
import seaborn as sns
import matplotlib.pyplot as plt

# Libs do LangChain e LangGraph
from langchain_community.llms import Ollama
from langgraph.graph import StateGraph, END

print("Dependências importadas com sucesso.")

# --- 1. CONFIGURAÇÃO DO MODELO E PROMPTS ---

# Defina o modelo Ollama a ser usado. Garanta que o Ollama esteja em execução.
OLLAMA_MODEL = "cniongolo/biomistral"
try:
    llm = Ollama(model=OLLAMA_MODEL, temperature=0.1)
    # Testa a conexão com o Ollama
    llm.invoke("Responda com 'OK' se estiver funcionando.")
    print(f"Conectado com sucesso ao modelo '{OLLAMA_MODEL}' via Ollama.")
except Exception as e:
    print(f"ERRO: Não foi possível conectar ao Ollama. Verifique se ele está em execução e se o modelo '{OLLAMA_MODEL}' foi baixado (`ollama run {OLLAMA_MODEL}`).")
    print(f"Detalhe do erro: {e}")
    exit()


# Este é o "cérebro" do agente. Um prompt detalhado que guia o LLM.
MASTER_PROMPT_TEMPLATE = """Você é um assistente de IA especialista em medicina, treinado para auxiliar profissionais de saúde.
Sua tarefa é analisar um conjunto de dados clínicos em formato JSON e gerar um resumo narrativo claro, estruturado e objetivo para um relatório clínico.

**REGRAS IMPORTANTES:**
1.  **Objetividade:** Analise apenas os dados fornecidos. Não invente informações.
2.  **Terminologia:** Use terminologia médica apropriada, mas de forma clara.
3.  **Segurança:** NUNCA forneça um diagnóstico definitivo. Aponte achados anormais usando frases como "sugere", "indica", "requer atenção".
4.  **Estrutura:** Formate a saída em Markdown com os seguintes títulos: "Resumo Geral", "Sinais Vitais", e "Resultados Laboratoriais".

**DADOS DE ENTRADA (JSON):**
```json
{clinical_data}
````"""

# --- 2. DEFINIÇÃO DAS FERRAMENTAS DE VISUALIZAÇÃO ---

def create_interactive_line_chart(data: dict, title: str) -> str:
    """Cria um gráfico de linhas interativo com Plotly e retorna como HTML."""
    try:
        df = pd.DataFrame(data)
        x_axis = df.columns[0]
        y_axes = df.columns[1:]
        fig = px.line(df, x=x_axis, y=y_axes, title=title, markers=True, template="plotly_white")
        fig.update_layout(legend_title_text='Métricas')
        return pio.to_html(fig, full_html=False, include_plotlyjs='cdn')
    except Exception as e:
        return f"<p><i>Erro ao gerar gráfico de linhas: {e}</i></p>"

def create_static_bar_chart(data: dict, title: str) -> str:
    """Cria um gráfico de barras estático com Seaborn e retorna como uma tag <img> em base64."""
    try:
        df = pd.DataFrame(list(data.items()), columns=['Métrica', 'Valor'])
        plt.figure(figsize=(8, 5))
        sns.barplot(data=df, x='Métrica', y='Valor')
        plt.title(title)
        plt.ylabel("Valor")
        plt.xticks(rotation=15, ha='right')
        buf = BytesIO()
        plt.savefig(buf, format="png", bbox_inches='tight')
        plt.close()
        data_b64 = base64.b64encode(buf.getbuffer()).decode("ascii")
        return f'<img src="data:image/png;base64,{data_b64}" alt="{title}"/>'
    except Exception as e:
        return f"<p><i>Erro ao gerar gráfico de barras: {e}</i></p>"


# --- 3. DEFINIÇÃO DO AGENTE COM LANGGRAPH ---

class AgentState(TypedDict):
    clinical_data: Dict
    summary_text: str
    visualization_plan: List[Dict]
    visualizations: List[str]
    final_report: str

def analysis_node(state: AgentState):
    print(">>> (Nó 1) Analisando dados e gerando resumo...")
    prompt = MASTER_PROMPT_TEMPLATE.format(clinical_data=json.dumps(state['clinical_data']))
    summary = llm.invoke(prompt)
    return {"summary_text": summary.strip()}

def visualization_planning_node(state: AgentState):
    print(">>> (Nó 2) Planejando visualizações...")
    prompt = f"""Com base nos seguintes dados clínicos, decida quais gráficos gerar.
Dados: {json.dumps(state['clinical_data'])}
Responda APENAS com uma lista de JSON, uma para cada gráfico.
Tipos de gráficos disponíveis: 'interactive_line', 'static_bar'.
Cada JSON deve ter: "chart_type", "title" e "data_subset"."""
    response = llm.invoke(prompt)
    try:
        # Tenta carregar a resposta como JSON
        plan = json.loads(response.strip())
    except json.JSONDecodeError:
        print("AVISO: LLM não retornou um JSON válido para o plano de visualização. Nenhum gráfico será gerado.")
        plan = []
    return {"visualization_plan": plan}

def visualization_execution_node(state: AgentState):
    print(">>> (Nó 3) Gerando os gráficos planejados...")
    visualizations = []
    for plan_item in state.get("visualization_plan", []):
        chart_type = plan_item.get("chart_type")
        data_subset = plan_item.get("data_subset")
        title = plan_item.get("title")
        if not all([chart_type, data_subset, title]): continue
        if chart_type == 'interactive_line':
            visualizations.append(create_interactive_line_chart(data_subset, title))
        elif chart_type == 'static_bar':
            visualizations.append(create_static_bar_chart(data_subset, title))
    return {"visualizations": visualizations}

def report_compilation_node(state: AgentState):
    print(">>> (Nó 4) Compilando o relatório final...")
    # Converte o texto markdown do resumo para HTML
    summary_html = "<br>".join(state['summary_text'].splitlines())
    # Junta as visualizações
    visualizations_html = "".join(state['visualizations'])

    report_html = f"""<!DOCTYPE html>
<html lang="pt-BR">
<head>
    <meta charset="UTF-8">
    <title>Relatório Clínico</title>
    <style>
        body {{ font-family: sans-serif; line-height: 1.6; margin: 0 auto; max-width: 900px; padding: 20px; }}
        h1, h2 {{ color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 5px;}}
        .report-section {{ margin-bottom: 30px; padding: 20px; background-color: #f8f9f9; border: 1px solid #d5dbdb; border-radius: 8px; }}
        img {{ max-width: 100%; height: auto; display: block; margin: 20px auto; box-shadow: 0 4px 8px rgba(0,0,0,0.1); }}
        .plotly-graph-div {{ margin: 20px auto; }}
    </style>
</head>
<body>
    <h1>Relatório Clínico Gerado por IA</h1>
    <div class="report-section">
        <h2>Análise Narrativa</h2>
        <p>{summary_html}</p>
    </div>
    <div class="report-section">
        <h2>Visualizações de Dados</h2>
        {visualizations_html}
    </div>
</body>
</html>"""
    return {"final_report": report_html}

# Construção do Grafo
workflow = StateGraph(AgentState)
workflow.add_node("analise", analysis_node)
workflow.add_node("planejamento_viz", visualization_planning_node)
workflow.add_node("execucao_viz", visualization_execution_node)
workflow.add_node("compilacao", report_compilation_node)

# Definição das Arestas
workflow.set_entry_point("analise")
workflow.add_edge("analise", "planejamento_viz")
workflow.add_edge("planejamento_viz", "execucao_viz")
workflow.add_edge("execucao_viz", "compilacao")
workflow.add_edge("compilacao", END)

# Compilação do App
app = workflow.compile()
print("Grafo LangGraph compilado com sucesso.")

# --- 4. FUNÇÃO PRINCIPAL E EXECUÇÃO ---

def generate_clinical_report(patient_data: dict) -> str:
    """
    Função principal que encapsula o agente LangGraph.
    """
    initial_state = {"clinical_data": patient_data}
    final_state = app.invoke(initial_state)
    return final_state.get("final_report", "<h1>Erro: Não foi possível gerar o relatório.</h1>")

if __name__ == "__main__":

    # Dados de exemplo para o paciente
    dados_paciente_exemplo = {
        "paciente_id": "P-78901", "idade": 68, "sexo": "F",
        "historico": "Hipertensão Arterial Sistêmica, Diabetes Mellitus tipo 2",
        "sinais_vitais": {
            "hora": [0, 8, 16, 24], "fc_bpm": [88, 95, 92, 86],
            "pa_sistolica_mmhg": [155, 162, 158, 150], "temperatura_c": [36.8, 37.1, 37.0, 36.7]
        },
        "labs": {
            "hemoglobina_g_dl": 11.5, "leucocitos_mm3": 12500, "plaquetas_mm3": 250000,
            "glicemia_jejum_mg_dl": 180, "creatinina_mg_dl": 1.4
        }
    }

    print("\n" + "="*50 + "\nIniciando a geração do relatório...\n" + "="*50)

    # Gera o relatório
    report_html_output = generate_clinical_report(dados_paciente_exemplo)

    # Salva o relatório final em um arquivo HTML
    output_filename = "relatorio_clinico_final.html"
    with open(output_filename, "w", encoding="utf-8") as f:
        f.write(report_html_output)

    print("\n" + "="*50 + f"\nRelatório gerado! Abra o arquivo '{output_filename}' no seu navegador.\n" + "="*50)
# Out:
# Dependências importadas com sucesso.
# /tmp/ipykernel_1920/1194771034.py:25: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model=OLLAMA_MODEL, temperature=0.1)
# Conectado com sucesso ao modelo 'cniongolo/biomistral' via Ollama.
# Grafo LangGraph compilado com sucesso.
#
# ==================================================
# Iniciando a geração do relatório...
# ==================================================
# >>> (Nó 1) Analisando dados e gerando resumo...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 208
#     205 print("\n" + "="*50 + "\nIniciando a geração do relatório...\n" + "="*50)
#     207 # Gera o relatório
# --> 208 report_html_output = generate_clinical_report(dados_paciente_exemplo)
#     210 # Salva o relatório final em um arquivo HTML
#     211 output_filename = "relatorio_clinico_final.html"
#
# Cell In[1], line 186, in generate_clinical_report(patient_data)
#     182 """
#     183 Função principal que encapsula o agente LangGraph.
#     184 """
#     185 initial_state = {"clinical_data": patient_data}
# --> 186 final_state = app.invoke(initial_state)
#     187 return final_state.get("final_report", "<h1>Erro: Não foi possível gerar o relatório.</h1>")
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langgraph/pregel/__init__.py:2843, in Pregel.invoke(self, input, config, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, **kwargs)
#    2840 chunks: list[dict[str, Any] | Any] = []
#    2841 interrupts: list[Interrupt] = []
# -> 2843 for chunk in self.stream(
#    2844     input,
#    2845     config,
#    2846     stream_mode=["updates", "values"]
#    2847     if stream_mode == "values"
#    2848     else stream_mode,
#    2849     print_mode=print_mode,
#    2850     output_keys=output_keys,
#    2851     interrupt_before=interrupt_before,
#    2852     interrupt_after=interrupt_after,
#    2853     **kwargs,
#    2854 ):
#    2855     if stream_mode == "values":
#    2856         if len(chunk) == 2:
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langgraph/pregel/__init__.py:2533, in Pregel.stream(self, input, config, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2531 for task in loop.match_cached_writes():
#    2532     loop.output_writes(task.id, task.writes, cached=True)
# -> 2533 for _ in runner.tick(
#    2534     [t for t in loop.tasks.values() if not t.writes],
#    2535     timeout=self.step_timeout,
#    2536     get_waiter=get_waiter,
#    2537     schedule_task=loop.accept_push,
#    2538 ):
#    2539     # emit output
#    2540     yield from _output(
#    2541         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2542     )
#    2543 loop.after_tick()
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langgraph/pregel/runner.py:162, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     160 t = tasks[0]
#     161 try:
# --> 162     run_with_retry(
#     163         t,
#     164         retry_policy,
#     165         configurable={
#     166             CONFIG_KEY_CALL: partial(
#     167                 _call,
#     168                 weakref.ref(t),
#     169                 retry_policy=retry_policy,
#     170                 futures=weakref.ref(futures),
#     171                 schedule_task=schedule_task,
#     172                 submit=self.submit,
#     173             ),
#     174         },
#     175     )
#     176     self.commit(t, None)
#     177 except Exception as exc:
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langgraph/pregel/retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langgraph/utils/runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langgraph/utils/runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# Cell In[1], line 94, in analysis_node(state)
#      92 print(">>> (Nó 1) Analisando dados e gerando resumo...")
#      93 prompt = MASTER_PROMPT_TEMPLATE.format(clinical_data=json.dumps(state['clinical_data']))
# ---> 94 summary = llm.invoke(prompt)
#      95 return {"summary_text": summary.strip()}
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langchain_core/language_models/llms.py:389, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     378 @override
#     379 def invoke(
#     380     self,
#    (...)
#     385     **kwargs: Any,
#     386 ) -> str:
#     387     config = ensure_config(config)
#     388     return (
# --> 389         self.generate_prompt(
#     390             [self._convert_input(input)],
#     391             stop=stop,
#     392             callbacks=config.get("callbacks"),
#     393             tags=config.get("tags"),
#     394             metadata=config.get("metadata"),
#     395             run_name=config.get("run_name"),
#     396             run_id=config.pop("run_id", None),
#     397             **kwargs,
#     398         )
#     399         .generations[0][0]
#     400         .text
#     401     )
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langchain_core/language_models/llms.py:766, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     757 @override
#     758 def generate_prompt(
#     759     self,
#    (...)
#     763     **kwargs: Any,
#     764 ) -> LLMResult:
#     765     prompt_strings = [p.to_string() for p in prompts]
# --> 766     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langchain_core/language_models/llms.py:973, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     958 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     959     run_managers = [
#     960         callback_manager.on_llm_start(
#     961             self._serialized,
#    (...)
#     971         )
#     972     ]
# --> 973     return self._generate_helper(
#     974         prompts,
#     975         stop,
#     976         run_managers,
#     977         new_arg_supported=bool(new_arg_supported),
#     978         **kwargs,
#     979     )
#     980 if len(missing_prompts) > 0:
#     981     run_managers = [
#     982         callback_managers[idx].on_llm_start(
#     983             self._serialized,
#    (...)
#     990         for idx in missing_prompt_idxs
#     991     ]
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langchain_core/language_models/llms.py:792, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     781 def _generate_helper(
#     782     self,
#     783     prompts: list[str],
#    (...)
#     788     **kwargs: Any,
#     789 ) -> LLMResult:
#     790     try:
#     791         output = (
# --> 792             self._generate(
#     793                 prompts,
#     794                 stop=stop,
#     795                 # TODO: support multiple run managers
#     796                 run_manager=run_managers[0] if run_managers else None,
#     797                 **kwargs,
#     798             )
#     799             if new_arg_supported
#     800             else self._generate(prompts, stop=stop)
#     801         )
#     802     except BaseException as e:
#     803         for run_manager in run_managers:
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langchain_community/llms/ollama.py:437, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     435 generations = []
#     436 for prompt in prompts:
# --> 437     final_chunk = super()._stream_with_aggregation(
#     438         prompt,
#     439         stop=stop,
#     440         images=images,
#     441         run_manager=run_manager,
#     442         verbose=self.verbose,
#     443         **kwargs,
#     444     )
#     445     generations.append([final_chunk])
#     446 return LLMResult(generations=generations)
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langchain_community/llms/ollama.py:349, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     340 def _stream_with_aggregation(
#     341     self,
#     342     prompt: str,
#    (...)
#     346     **kwargs: Any,
#     347 ) -> GenerationChunk:
#     348     final_chunk: Optional[GenerationChunk] = None
# --> 349     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     350         if stream_resp:
#     351             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langchain_community/llms/ollama.py:194, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     186 def _create_generate_stream(
#     187     self,
#     188     prompt: str,
#    (...)
#     191     **kwargs: Any,
#     192 ) -> Iterator[str]:
#     193     payload = {"prompt": prompt, "images": images}
# --> 194     yield from self._create_stream(
#     195         payload=payload,
#     196         stop=stop,
#     197         api_url=f"{self.base_url}/api/generate",
#     198         **kwargs,
#     199     )
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/langchain_community/llms/ollama.py:252, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     246 else:
#     247     request_payload = {
#     248         "prompt": payload.get("prompt"),
#     249         "images": payload.get("images", []),
#     250         **params,
#     251     }
# --> 252 response = requests.post(
#     253     url=api_url,
#     254     headers={
#     255         "Content-Type": "application/json",
#     256         **(self.headers if isinstance(self.headers, dict) else {}),
#     257     },
#     258     auth=self.auth,
#     259     json=request_payload,
#     260     stream=True,
#     261     timeout=self.timeout,
#     262 )
#     263 response.encoding = "utf-8"
#     264 if response.status_code != 200:
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/mestrado/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Arquivo: agente_relatorios.py (Versão Final Corrigida)
# Descrição: Agente de IA para geração de relatórios clínicos com LangGraph e Ollama.
#
import json
import base64
from io import BytesIO
from typing import TypedDict, List, Dict

# Libs de Visualização
import pandas as pd
import plotly.express as px
import plotly.io as pio
import seaborn as sns
import matplotlib.pyplot as plt

# Libs do LangChain e LangGraph
# AVISO DE DEPRECIAÇÃO: A classe Ollama foi movida. Para remover o aviso,
# instale a nova biblioteca com `pip install langchain-ollama`
# e mude a importação para: `from langchain_ollama import OllamaLLM as Ollama`
from langchain_community.llms import Ollama
from langgraph.graph import StateGraph, END

print("Dependências importadas com sucesso.")

# --- 1. CONFIGURAÇÃO DO MODELO E PROMPTS ---

# Defina o modelo Ollama a ser usado. Garanta que o Ollama esteja em execução.
# O desempenho pode variar entre modelos. Se este não funcionar, 'pubmed-mistral' é uma alternativa.
#OLLAMA_MODEL = "cniongolo/biomistral"
#OLLAMA_MODEL = "phi3"
OLLAMA_MODEL = "medllama2"
try:
    llm = Ollama(model=OLLAMA_MODEL, temperature=0.1)
    # Testa a conexão com o Ollama
    llm.invoke("Responda com 'OK' se estiver funcionando.")
    print(f"Conectado com sucesso ao modelo '{OLLAMA_MODEL}' via Ollama.")
except Exception as e:
    print(f"ERRO: Não foi possível conectar ao Ollama. Verifique se ele está em execução e se o modelo '{OLLAMA_MODEL}' foi baixado (`ollama run {OLLAMA_MODEL}`).")
    print(f"Detalhe do erro: {e}")
    exit()


# PROMPT REFORÇADO (Nó 1): Instruções mais diretas para o resumo narrativo.
MASTER_PROMPT_TEMPLATE = """ATENÇÃO: Sua resposta deve ser exclusivamente em Português do Brasil.

Você é um assistente de IA especialista em medicina. Sua única tarefa é gerar um resumo narrativo a partir dos dados clínicos em JSON abaixo. Siga estritamente a estrutura de formatação com os títulos "Resumo Geral", "Sinais Vitais", e "Resultados Laboratoriais".

**DADOS CLÍNICOS:**
```json
{clinical_data}
```

**RELATÓRIO GERADO:**
"""

# --- 2. DEFINIÇÃO DAS FERRAMENTAS DE VISUALIZAÇÃO ---

def create_interactive_line_chart(data: dict, title: str) -> str:
    """Cria um gráfico de linhas interativo com Plotly e retorna como HTML."""
    try:
        df = pd.DataFrame(data)
        x_axis = df.columns[0]
        y_axes = df.columns[1:]
        fig = px.line(df, x=x_axis, y=y_axes, title=title, markers=True, template="plotly_white")
        fig.update_layout(legend_title_text='Métricas')
        return pio.to_html(fig, full_html=False, include_plotlyjs='cdn')
    except Exception as e:
        return f"<p><i>Erro ao gerar gráfico de linhas: {e}</i></p>"

def create_static_bar_chart(data: dict, title: str) -> str:
    """Cria um gráfico de barras estático com Seaborn e retorna como uma tag <img> em base64."""
    try:
        df = pd.DataFrame(list(data.items()), columns=['Métrica', 'Valor'])
        plt.figure(figsize=(8, 5))
        sns.barplot(data=df, x='Métrica', y='Valor')
        plt.title(title)
        plt.ylabel("Valor")
        plt.xticks(rotation=15, ha='right')
        buf = BytesIO()
        plt.savefig(buf, format="png", bbox_inches='tight')
        plt.close()
        data_b64 = base64.b64encode(buf.getbuffer()).decode("ascii")
        return f'<img src="data:image/png;base64,{data_b64}" alt="{title}"/>'
    except Exception as e:
        return f"<p><i>Erro ao gerar gráfico de barras: {e}</i></p>"


# --- 3. DEFINIÇÃO DO AGENTE COM LANGGRAPH ---

class AgentState(TypedDict):
    clinical_data: Dict
    summary_text: str
    visualization_plan: List[Dict]
    visualizations: List[str]
    final_report: str

def analysis_node(state: AgentState):
    """Nó 1: Analisa os dados e gera o resumo em texto com o LLM."""
    print(">>> (Nó 1) Analisando dados e gerando resumo...")
    prompt = MASTER_PROMPT_TEMPLATE.format(clinical_data=json.dumps(state['clinical_data']))
    summary = llm.invoke(prompt)
    return {"summary_text": summary.strip()}

def visualization_planning_node(state: AgentState):
    """Nó 2: Usa o LLM para planejar quais visualizações criar (com prompt robustecido)."""
    print(">>> (Nó 2) Planejando visualizações...")

    # PROMPT REFORÇADO (Nó 2): Instruções mais imperativas para a geração de JSON.
    prompt = f"""Você é um robô gerador de JSON. Sua única tarefa é criar um plano de visualização com base nos dados abaixo.

**REGRAS CRÍTICAS:**
1.  Sua resposta deve ser **APENAS** o código JSON.
2.  Não escreva nenhuma explicação, saudação ou qualquer texto fora do JSON.
3.  Sua resposta deve começar com `[` e terminar com `]`.

---
**EXEMPLO DE RESPOSTA PERFEITA:**
```json
[
    {{
        "chart_type": "interactive_line",
        "title": "Evolução dos Sinais Vitais",
        "data_subset": {{
            "hora": [0, 8, 16],
            "fc_bpm": [80, 85, 82]
        }}
    }},
    {{
        "chart_type": "static_bar",
        "title": "Resultados Laboratoriais",
        "data_subset": {{
            "hemoglobina_g_dl": 12.1,
            "leucocitos_mm3": 9800
        }}
    }}
]
```
---

**TAREFA REAL:**

## DADOS PARA ANÁLISE:
```json
{json.dumps(state['clinical_data'])}
```

## GERE O JSON AGORA:
"""
    response = llm.invoke(prompt)

    # Limpa a resposta para garantir que estamos tentando decodificar apenas o JSON
    clean_response = response.strip()
    if "```json" in clean_response:
        clean_response = clean_response.split("```json")[1].split("```")[0]
    
    if not clean_response:
        print("AVISO: LLM retornou uma resposta vazia para o plano de visualização.")
        plan = []
    else:
        try:
            plan = json.loads(clean_response)
        except json.JSONDecodeError as e:
            print(f"AVISO: LLM ainda não retornou um JSON válido. Erro: {e}")
            print(f"Resposta recebida do LLM:\\n---\\n{response}\\n---")
            plan = []

    return {"visualization_plan": plan}


def visualization_execution_node(state: AgentState):
    """Nó 3: Executa o plano e cria os gráficos usando as ferramentas."""
    print(">>> (Nó 3) Gerando os gráficos planejados...")
    visualizations = []
    plan = state.get("visualization_plan", [])
    if not plan:
        print("Nenhum plano de visualização encontrado para executar.")
        return {"visualizations": []}
        
    for plan_item in plan:
        chart_type = plan_item.get("chart_type")
        data_subset = plan_item.get("data_subset")
        title = plan_item.get("title")
        if not all([chart_type, data_subset, title]): continue
        if chart_type == 'interactive_line':
            visualizations.append(create_interactive_line_chart(data_subset, title))
        elif chart_type == 'static_bar':
            visualizations.append(create_static_bar_chart(data_subset, title))
    return {"visualizations": visualizations}

def report_compilation_node(state: AgentState):
    """Nó 4: Compila o texto e as visualizações em um relatório HTML final."""
    print(">>> (Nó 4) Compilando o relatório final...")
    # Converte o texto markdown do resumo para HTML
    summary_html = "<br>".join(state['summary_text'].splitlines())
    # Junta as visualizações
    visualizations_html = "".join(state['visualizations'])

    report_html = f"""<!DOCTYPE html>
<html lang="pt-BR">
<head>
    <meta charset="UTF-8">
    <title>Relatório Clínico</title>
    <style>
        body {{ font-family: sans-serif; line-height: 1.6; margin: 0 auto; max-width: 900px; padding: 20px; }}
        h1, h2 {{ color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 5px;}}
        .report-section {{ margin-bottom: 30px; padding: 20px; background-color: #f8f9f9; border: 1px solid #d5dbdb; border-radius: 8px; }}
        img {{ max-width: 100%; height: auto; display: block; margin: 20px auto; box-shadow: 0 4px 8px rgba(0,0,0,0.1); }}
        .plotly-graph-div {{ margin: 20px auto; }}
    </style>
</head>
<body>
    <h1>Relatório Clínico Gerado por IA</h1>
    <div class="report-section">
        <h2>Análise Narrativa</h2>
        <p>{summary_html}</p>
    </div>
    <div class="report-section">
        <h2>Visualizações de Dados</h2>
        {visualizations_html if visualizations_html else "<p><i>Nenhuma visualização foi gerada.</i></p>"}
    </div>
</body>
</html>"""
    return {"final_report": report_html}

# Construção do Grafo
workflow = StateGraph(AgentState)
workflow.add_node("analise", analysis_node)
workflow.add_node("planejamento_viz", visualization_planning_node)
workflow.add_node("execucao_viz", visualization_execution_node)
workflow.add_node("compilacao", report_compilation_node)

# Definição das Arestas
workflow.set_entry_point("analise")
workflow.add_edge("analise", "planejamento_viz")
workflow.add_edge("planejamento_viz", "execucao_viz")
workflow.add_edge("execucao_viz", "compilacao")
workflow.add_edge("compilacao", END)

# Compilação do App
app = workflow.compile()
print("Grafo LangGraph compilado com sucesso.")

# --- 4. FUNÇÃO PRINCIPAL E EXECUÇÃO ---

def generate_clinical_report(patient_data: dict) -> str:
    """
    Função principal que encapsula o agente LangGraph.
    """
    initial_state = {"clinical_data": patient_data}
    final_state = app.invoke(initial_state)
    return final_state.get("final_report", "<h1>Erro: Não foi possível gerar o relatório.</h1>")

if __name__ == "__main__":

    # Dados de exemplo para o paciente
    dados_paciente_exemplo = {
        "paciente_id": "P-78901", "idade": 68, "sexo": "F",
        "historico": "Hipertensão Arterial Sistêmica, Diabetes Mellitus tipo 2",
        "sinais_vitais": {
            "hora": [0, 8, 16, 24], "fc_bpm": [88, 95, 92, 86],
            "pa_sistolica_mmhg": [155, 162, 158, 150], "temperatura_c": [36.8, 37.1, 37.0, 36.7]
        },
        "labs": {
            "hemoglobina_g_dl": 11.5, "leucocitos_mm3": 12500, "plaquetas_mm3": 250000,
            "glicemia_jejum_mg_dl": 180, "creatinina_mg_dl": 1.4
        }
    }

    print("\n" + "="*50 + "\nIniciando a geração do relatório...\n" + "="*50)

    # Gera o relatório
    report_html_output = generate_clinical_report(dados_paciente_exemplo)

    # Salva o relatório final em um arquivo HTML
    output_filename = "relatorio_clinico_final.html"
    with open(output_filename, "w", encoding="utf-8") as f:
        f.write(report_html_output)

    print("\n" + "="*50 + f"\nRelatório gerado! Abra o arquivo '{output_filename}' no seu navegador.\n" + "="*50)
# Out:
# Dependências importadas com sucesso.
# Conectado com sucesso ao modelo 'medllama2' via Ollama.
# Grafo LangGraph compilado com sucesso.
#
# ==================================================
# Iniciando a geração do relatório...
# ==================================================
# >>> (Nó 1) Analisando dados e gerando resumo...
# >>> (Nó 2) Planejando visualizações...
# AVISO: LLM ainda não retornou um JSON válido. Erro: Expecting value: line 1 column 1 (char 0)
# Resposta recebida do LLM:\n---\n
# Please provide the data for the visualization in a JSON format. The data should include the patient's ID, age, sex, medical history, vital signs (including heart rate), and laboratory results (including hemoglobin A1c).\n---
# >>> (Nó 3) Gerando os gráficos planejados...
# Nenhum plano de visualização encontrado para executar.
# >>> (Nó 4) Compilando o relatório final...
#
# ==================================================
# Relatório gerado! Abra o arquivo 'relatorio_clinico_final.html' no seu navegador.
# ==================================================

# %%
# Arquivo: agente_relatorios.py (Versão com Geração de Gráficos Determinística)
# Descrição: Agente de IA que usa o LLM para texto e lógica Python para gráficos.
#
import json
import base64
from io import BytesIO
from typing import TypedDict, List, Dict

# Libs de Visualização
import pandas as pd
import plotly.express as px
import plotly.io as pio
import seaborn as sns
import matplotlib.pyplot as plt

# Libs do LangChain e LangGraph
from langchain_community.llms import Ollama
from langgraph.graph import StateGraph, END

print("Dependências importadas com sucesso.")

# --- 1. CONFIGURAÇÃO DO MODELO E PROMPTS ---

OLLAMA_MODEL = "medllama2"
try:
    llm = Ollama(model=OLLAMA_MODEL, temperature=0.1)
    llm.invoke("Responda com 'OK' se estiver funcionando.")
    print(f"Conectado com sucesso ao modelo '{OLLAMA_MODEL}' via Ollama.")
except Exception as e:
    print(f"ERRO: Não foi possível conectar ao Ollama. Verifique se ele está em execução e se o modelo '{OLLAMA_MODEL}' foi baixado (`ollama run {OLLAMA_MODEL}`).")
    exit()

# PROMPT REFORÇADO (Nó 1): Instruções mais diretas para o resumo narrativo.
MASTER_PROMPT_TEMPLATE = """ATENÇÃO: Sua resposta deve ser exclusivamente em Português do Brasil.

Você é um assistente de IA especialista em medicina. Sua única tarefa é gerar um resumo narrativo a partir dos dados clínicos em JSON abaixo. Siga estritamente a estrutura de formatação com os títulos "Resumo Geral", "Sinais Vitais", e "Resultados Laboratoriais".

**DADOS CLÍNICOS:**
```json
{clinical_data}
```

**RELATÓRIO GERADO:**
"""

# --- 2. DEFINIÇÃO DAS FERRAMENTAS DE VISUALIZAÇÃO ---
# (As funções de criar gráficos permanecem as mesmas)

def create_interactive_line_chart(data: dict, title: str) -> str:
    """Cria um gráfico de linhas interativo com Plotly e retorna como HTML."""
    try:
        df = pd.DataFrame(data)
        x_axis = df.columns[0]
        y_axes = df.columns[1:]
        fig = px.line(df, x=x_axis, y=y_axes, title=title, markers=True, template="plotly_white")
        fig.update_layout(legend_title_text='Métricas')
        return pio.to_html(fig, full_html=False, include_plotlyjs='cdn')
    except Exception as e:
        return f"<p><i>Erro ao gerar gráfico de linhas: {e}</i></p>"

def create_static_bar_chart(data: dict, title: str) -> str:
    """Cria um gráfico de barras estático com Seaborn e retorna como uma tag <img> em base64."""
    try:
        df = pd.DataFrame(list(data.items()), columns=['Métrica', 'Valor'])
        plt.figure(figsize=(8, 5))
        sns.barplot(data=df, x='Métrica', y='Valor')
        plt.title(title)
        plt.ylabel("Valor")
        plt.xticks(rotation=15, ha='right')
        buf = BytesIO()
        plt.savefig(buf, format="png", bbox_inches='tight')
        plt.close()
        data_b64 = base64.b64encode(buf.getbuffer()).decode("ascii")
        return f'<img src="data:image/png;base64,{data_b64}" alt="{title}"/>'
    except Exception as e:
        return f"<p><i>Erro ao gerar gráfico de barras: {e}</i></p>"


# --- 3. DEFINIÇÃO DO AGENTE COM LANGGRAPH (ARQUITETURA SIMPLIFICADA) ---

class AgentState(TypedDict):
    clinical_data: Dict
    summary_text: str
    visualizations: List[str]  # Não precisamos mais do 'visualization_plan'
    final_report: str

def analysis_node(state: AgentState):
    """Nó 1: Analisa os dados e gera o resumo em texto com o LLM."""
    print(">>> (Nó 1) Analisando dados e gerando resumo...")
    prompt = MASTER_PROMPT_TEMPLATE.format(clinical_data=json.dumps(state['clinical_data']))
    summary = llm.invoke(prompt)
    return {"summary_text": summary.strip()}

def deterministic_visualization_node(state: AgentState):
    """Nó 2: Gera gráficos de forma determinística com base na estrutura dos dados."""
    print(">>> (Nó 2) Gerando gráficos com lógica Python...")
    visualizations = []
    data = state.get("clinical_data", {})

    # REGRA 1: Se houver 'sinais_vitais', crie um gráfico de linhas.
    if "sinais_vitais" in data and isinstance(data["sinais_vitais"], dict):
        print("   - Encontrados dados de 'sinais_vitais'. Gerando gráfico de linhas.")
        sinais_vitais_data = data["sinais_vitais"]
        visualizations.append(create_interactive_line_chart(sinais_vitais_data, "Evolução dos Sinais Vitais"))

    # REGRA 2: Se houver 'labs', crie um gráfico de barras.
    if "labs" in data and isinstance(data["labs"], dict):
        print("   - Encontrados dados de 'labs'. Gerando gráfico de barras.")
        labs_data = data["labs"]
        visualizations.append(create_static_bar_chart(labs_data, "Resultados Laboratoriais"))
    
    if not visualizations:
        print("   - Nenhum dado apropriado para visualização foi encontrado.")

    return {"visualizations": visualizations}

def report_compilation_node(state: AgentState):
    """Nó 3: Compila o texto e as visualizações em um relatório HTML final."""
    print(">>> (Nó 3) Compilando o relatório final...")
    summary_html = "<br>".join(state.get('summary_text', '').splitlines())
    visualizations_html = "".join(state.get('visualizations', []))

    report_html = f"""<!DOCTYPE html>
<html lang="pt-BR">
<head>
    <meta charset="UTF-8">
    <title>Relatório Clínico</title>
    <style>
        body {{ font-family: sans-serif; line-height: 1.6; margin: 0 auto; max-width: 900px; padding: 20px; }}
        h1, h2 {{ color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 5px;}}
        .report-section {{ margin-bottom: 30px; padding: 20px; background-color: #f8f9f9; border: 1px solid #d5dbdb; border-radius: 8px; }}
        img {{ max-width: 100%; height: auto; display: block; margin: 20px auto; box-shadow: 0 4px 8px rgba(0,0,0,0.1); }}
        .plotly-graph-div {{ margin: 20px auto; }}
    </style>
</head>
<body>
    <h1>Relatório Clínico Gerado por IA</h1>
    <div class="report-section">
        <h2>Análise Narrativa</h2>
        <p>{summary_html}</p>
    </div>
    <div class="report-section">
        <h2>Visualizações de Dados</h2>
        {visualizations_html if visualizations_html else "<p><i>Nenhuma visualização foi gerada.</i></p>"}
    </div>
</body>
</html>"""
    return {"final_report": report_html}

# Construção do Grafo (mais simples agora)
workflow = StateGraph(AgentState)
workflow.add_node("analise", analysis_node)
workflow.add_node("geracao_determinista_viz", deterministic_visualization_node)
workflow.add_node("compilacao", report_compilation_node)

# Definição das Arestas
workflow.set_entry_point("analise")
workflow.add_edge("analise", "geracao_determinista_viz")
workflow.add_edge("geracao_determinista_viz", "compilacao")
workflow.add_edge("compilacao", END)

# Compilação do App
app = workflow.compile()
print("Grafo LangGraph compilado com sucesso.")

# --- 4. FUNÇÃO PRINCIPAL E EXECUÇÃO ---

def generate_clinical_report(patient_data: dict) -> str:
    """Função principal que encapsula o agente LangGraph."""
    initial_state = {"clinical_data": patient_data}
    final_state = app.invoke(initial_state)
    return final_state.get("final_report", "<h1>Erro: Não foi possível gerar o relatório.</h1>")

if __name__ == "__main__":
    dados_paciente_exemplo = {
        "paciente_id": "P-78901", "idade": 68, "sexo": "F",
        "historico": "Hipertensão Arterial Sistêmica, Diabetes Mellitus tipo 2",
        "sinais_vitais": {
            "hora": [0, 8, 16, 24], "fc_bpm": [88, 95, 92, 86],
            "pa_sistolica_mmhg": [155, 162, 158, 150], "temperatura_c": [36.8, 37.1, 37.0, 36.7]
        },
        "labs": {
            "hemoglobina_g_dl": 11.5, "leucocitos_mm3": 12500, "plaquetas_mm3": 250000,
            "glicemia_jejum_mg_dl": 180, "creatinina_mg_dl": 1.4
        }
    }
    
    print("\n" + "="*50 + "\nIniciando a geração do relatório...\n" + "="*50)
    report_html_output = generate_clinical_report(dados_paciente_exemplo)
    output_filename = "relatorio_clinico_final.html"
    with open(output_filename, "w", encoding="utf-8") as f:
        f.write(report_html_output)
        
    print("\n" + "="*50 + f"\nRelatório gerado! Abra o arquivo '{output_filename}' no seu navegador.\n" + "="*50)
# Out:
# Dependências importadas com sucesso.
# /tmp/ipykernel_456/2927279805.py:26: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model=OLLAMA_MODEL, temperature=0.1)
# Conectado com sucesso ao modelo 'medllama2' via Ollama.
# Grafo LangGraph compilado com sucesso.
#
# ==================================================
# Iniciando a geração do relatório...
# ==================================================
# >>> (Nó 1) Analisando dados e gerando resumo...
# >>> (Nó 2) Gerando gráficos com lógica Python...
#    - Encontrados dados de 'sinais_vitais'. Gerando gráfico de linhas.
#    - Encontrados dados de 'labs'. Gerando gráfico de barras.
# >>> (Nó 3) Compilando o relatório final...
#
# ==================================================
# Relatório gerado! Abra o arquivo 'relatorio_clinico_final.html' no seu navegador.
# ==================================================
